# %%
import time
import random

print('Testing, testing....')
time.sleep(1)
print('AHhh, YEs, fINaLlY, THe cOnEcCTiOn eS cOMpLEtE!')
time.sleep(random.uniform(1,5))
print('hElLO CiTISeNs oF eRTh')
time.sleep(random.uniform(1,5))

leader = input('wHAts YOur lAdDeR CAlLed? TElL mIe nW!')
time.sleep(random.uniform(1,5))

print('tAke miE tO', leader)
time.sleep(random.uniform(1,5))

name = input('aHh YEs, eE fOogot dO ASk dOUr aIm. VUt eEs eEt?') 
if name == 'Skyla':
    print('📚🐲️')
elif name == 'Eva Evergreen':
    print('🦊🔥🪄⭐')
elif name == 'Tootsie':
    print('🐈‍⬛🐈‍🦥🦊🐍🐲🦋')
    
time.sleep(random.uniform(1,5))

print('wElL,', name ,' , pLZd dO AVe yU.')
time.sleep(random.uniform(1,5))

for counter in range(1, 6):
     print('PLZ STAND BY')
     time.sleep(random.uniform(1,5))



print('loading....loading....loading.....')
time.sleep(random.uniform(1,5))

print('Later........................................................................................................')
time.sleep(random.uniform(1,5))

print('WARNING! INCOMING AD!')
time.sleep(random.uniform(1,5))

print('Hi Guys! Its Jerry The Dinosaur(🦖) Here, And Today Im ADdressing The Fact That DRAGONS ARE BAD. So We Are Making A Servant System That Involves Dragons! Rent One Today! (I personally HATE these ads. Vive les dragons!(🇫🇷).)')  
time.sleep(random.uniform(1,5))

print('now, back to the story......')
time.sleep(random.uniform(1,5))

how_question = 'sAY,'+ name + ' HOw mUCh lONgER?'
time.sleep(random.uniform(1,5))

how = input(how_question)
time.sleep(random.uniform(1,5))

print(how,'!!!!!! tHaTs aH loO0ng tIMe!!!!!!!')
time.sleep(random.uniform(1,5))

print('"lets skip ahead."')
time.sleep(random.uniform(1,5))

print('Later.........')
time.sleep(random.uniform(1,5))

print('wEre ErE!')
time.sleep(random.uniform(1,5))

print('wEVe REacHEd tHE pLAcE F', leader ,'!')
time.sleep(random.uniform(1,5))

print('nOW sHAlL vE Go iN?')
time.sleep(random.uniform(1,5))

print('ElLO,', leader ,'hONeRD dO mEeT U.')
time.sleep(random.uniform(1,5))
      
print(leader , ': Well, well, well, its the troblesome AlienHead and...', name ,'?......Is that you?')
time.sleep(random.uniform(1,5))

print('You: ........Wyvrn? What?!')
time.sleep(random.uniform(1,5))

print('                      TO BE CONTINUED                 ')
time.sleep(random.uniform(1,5))

# %% [markdown]
# You can access this code and program at: https://tinyurl.com/2shufsry
#
# We used Jupyter Notebooks to do this demo:
#
# https://jupyter.org/try-jupyter/
#
# Or Google Colab:
#
# https://colab.research.google.com
#
# This is what the program output looks like:
#
# AHhh, YEs, fINaLlY, THe cOnEcCTiOn eS cOMpLEtE!
# hElLO CiTISeNs oF eRTh
# wHAts YOur lAdDeR CAlLed? TElL mIe nW!boba
# tAke miE tO boba
# aHh YEs, eE fOogot dO ASk dOUr aIm. VUt eEs eEt?Eva Evergreen
# 🦊🔥🪄⭐
# wElL, Eva Evergreen  , pLZd dO AVe yU.
# PLZ STAND BY
# PLZ STAND BY
# PLZ STAND BY
# PLZ STAND BY
# PLZ STAND BY
# loading....loading....loading.....
# Later........................................................................................................
# WARNING! INCOMING AD!
# Hi Guys! Its Jerry The Dinosaur(🦖) Here, And Today Im ADdressing The Fact That DRAGONS ARE BAD. So We Are Making A Servant System That Involves Dragons! Rent One Today! (I personally HATE these ads. Vive les dragons!(🇫🇷).)
# now, back to the story......
# sAY,Eva Evergreen HOw mUCh lONgER?10 Universes
# 10 Universes !!!!!! tHaTs aH loO0ng tIMe!!!!!!!
# "lets skip ahead."
# Later.........
# wEre ErE!
# wEVe REacHEd tHE pLAcE F boba !
# nOW sHAlL vE Go iN?
# ElLO, boba hONeRD dO mEeT U.
# boba : Well, well, well, its the troblesome AlienHead and... Eva Evergreen ?......Is that you?
# You: ........Wyvrn? What?!
#                       TO BE CONTINUED
